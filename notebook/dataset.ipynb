# %%
import sys
sys.path.append('/home/kdh/code/CLUE/')

# %%
from PIL import Image
img = Image.open('/home/kdh/code/CLUE/datasets/BMAD/BraTS2021_slice/train/good/00003_61.png')#.size#()

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=240x240>

# %%
from BraTS import BraTSDataset
dataset = BraTSDataset(base_dir='/home/kdh/code/CLUE/metadata', 
                       sequence='flair', 
                       view='coronal', 
                       split='train', 
                       transform=None)

# %%
import matplotlib.pyplot as plt
plt.imshow(dataset[0][0], cmap='gray')

# %%
plt.imshow(dataset[0][1])

# %%
import torch
import torch.nn as nn
m = nn.Sigmoid()
loss = nn.BCELoss()
i = torch.randn(3, 2, requires_grad=True)
print(i)
# Out:
# tensor([[ 0.4032,  0.6428],
#         [-0.6420, -2.1833],
#         [-0.0677,  0.1438]], requires_grad=True)

# %%
target = torch.rand(3, 2, requires_grad=False)
print(target)
# Out:
# tensor([[0.2894, 0.3529],
#         [0.7015, 0.3749],
#         [0.0134, 0.3205]])

# %%
print(m(i))
# Out:
# tensor([[0.5995, 0.6554],
#         [0.3448, 0.1013],
#         [0.4831, 0.5359]], grad_fn=<SigmoidBackward0>)

# %%
output = loss(m(i), target)
output.backward()

# %%
from CLIP import clip
model, _ = clip.load('ViT-L/14')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from CLIP import clip
#       2 model, _ = clip.load('ViT-L/14')
#
# ModuleNotFoundError: No module named 'CLIP'
